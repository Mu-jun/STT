# %%
from datasets import load_dataset
import pandas as pd
import numpy as np
import re
import json

from unicode import split_syllables, join_jamos
from tqdm import tqdm

# %% [markdown]
# ## Data Load

# %%
text = "text"

# %%
all_data = load_dataset('csv',data_files='./order_speech_ko.csv',split='train')
# Out:
# Using custom data configuration default-8e0d0b8910acc620
# Reusing dataset csv (C:\Users\Mu-jun\.cache\huggingface\datasets\csv\default-8e0d0b8910acc620\0.0.0\bf68a4c4aefa545d0712b2fcbb1b327f905bbe2f6425fbc5e8c25234acb9e14a)

# %% [markdown]
# ## Data Cleaning

# %%
chars_to_ignore_regex = '[\,\?\.\!\-\;\:\"\“\%\‘\”\�]'

def remove_special_characters(batch):
    batch[text] = re.sub(chars_to_ignore_regex, '', batch[text]).lower() + " "
    return batch

# %%
remove_spectial_char_data = all_data.map(remove_special_characters)
# Out:
# Parameter 'function'=<function remove_special_characters at 0x000001903D2100D8> of the transform datasets.arrow_dataset.Dataset._map_single couldn't be hashed properly, a random hash was used instead. Make sure your transforms and parameters are serializable with pickle or dill for the dataset fingerprinting and caching to work. If you reuse this transform, the caching mechanism will consider it to be different from the previous calls and recompute everything. This warning is only showed once. Subsequent hashing failures won't be showed.
#   0%|          | 0/142367 [00:00<?, ?ex/s]

# %% [markdown]
# ## Split to Font

# %%
def extract_all_chars(batch):
    all_text = " ".join(batch[text])
    vocab = list(set(all_text))
    return {"vocab": [vocab], "all_text": [all_text]}

# %%
char_vocab = remove_spectial_char_data.map(
    extract_all_chars,
    batched=True,
    batch_size=-1,
    keep_in_memory=True,
    remove_columns=remove_spectial_char_data.column_names)
# Out:
#   0%|          | 0/1 [00:00<?, ?ba/s]

# %% [markdown]
# ## Add index

# %%
vocab_list = list(set(char_vocab["vocab"][0]))

# %%
vocab_dict = {v: k+5 for k, v in enumerate(vocab_list)}

# %% [markdown]
# ## Add Special Token

# %%
vocab_dict["|"] = 4
vocab_dict["<pad>"] = 0
vocab_dict["<s>"] = 1
vocab_dict["</s>"] = 2
vocab_dict["<unk>"] = 3
len(vocab_dict)
# Out:
# 605

# %% [markdown]
# ## Export Vocabulary to json file

# %%
with open('vocab.json', 'w') as vocab_file:
    json.dump(vocab_dict, vocab_file)

# %%
vocab_dict
# Out:
# {'그': 5,
#  '떨': 6,
#  '궁': 7,
#  '했': 8,
#  '덤': 9,
#  '욱': 10,
#  '청': 11,
#  '깥': 12,
#  '겟': 13,
#  '갔': 14,
#  '습': 15,
#  '명': 16,
#  '반': 17,
#  '괜': 18,
#  '놓': 19,
#  '텔': 20,
#  '탑': 21,
#  '람': 22,
#  '호': 23,
#  '되': 24,
#  '가': 25,
#  '캐': 26,
#  '막': 27,
#  '원': 28,
#  '된': 29,
#  '하': 30,
#  '감': 31,
#  '달': 32,
#  '늦': 33,
#  '고': 34,
#  '갈': 35,
#  '익': 36,
#  '쫌': 37,
#  '등': 38,
#  '슬': 39,
#  '뀌': 40,
#  '쉼': 41,
#  '력': 42,
#  '모': 43,
#  '코': 44,
#  '프': 45,
#  '당': 46,
#  '체': 47,
#  '라': 48,
#  '귀': 49,
#  '메': 50,
#  '심': 51,
#  '존': 52,
#  '얘': 53,
#  '것': 54,
#  '미': 55,
#  '보': 56,
#  '직': 57,
#  '음': 58,
#  '닭': 59,
#  '셔': 60,
#  '킬': 61,
#  '광': 62,
#  '식': 63,
#  '떻': 64,
#  '연': 65,
#  '행': 66,
#  '말': 67,
#  '뭔': 68,
#  '오': 69,
#  '긴': 70,
#  '씬': 71,
#  '월': 72,
#  '둬': 73,
#  '엌': 74,
#  '렇': 75,
#  '와': 76,
#  '랑': 77,
#  '삼': 78,
#  '건': 79,
#  '몰': 80,
#  '딱': 81,
#  '린': 82,
#  '녹': 83,
#  '켤': 84,
#  '취': 85,
#  '봐': 86,
#  '까': 87,
#  '색': 88,
#  '머': 89,
#  '놔': 90,
#  '절': 91,
#  '남': 92,
#  '액': 93,
#  '꿀': 94,
#  '브': 95,
#  '총': 96,
#  '드': 97,
#  '답': 98,
#  '찾': 99,
#  '꺼': 100,
#  '흐': 101,
#  '낫': 102,
#  '한': 103,
#  '기': 104,
#  '좀': 105,
#  '눈': 106,
#  '자': 107,
#  '줄': 108,
#  '끝': 109,
#  '핫': 110,
#  '세': 111,
#  '뽑': 112,
#  '쪽': 113,
#  '뜰': 114,
#  '발': 115,
#  '끌': 116,
#  '낮': 117,
#  '크': 118,
#  '춰': 119,
#  '쫏': 120,
#  '빠': 121,
#  '팔': 122,
#  '스': 123,
#  '엔': 124,
#  '휴': 125,
#  'c': 126,
#  '방': 127,
#  '탁': 128,
#  '교': 129,
#  '더': 130,
#  '착': 131,
#  '악': 132,
#  '화': 133,
#  '곱': 134,
#  '우': 135,
#  '새': 136,
#  '순': 137,
#  '늘': 138,
#  '록': 139,
#  '증': 140,
#  '동': 141,
#  '걷': 142,
#  '울': 143,
#  '량': 144,
#  '외': 145,
#  '길': 146,
#  '십': 147,
#  '른': 148,
#  '밤': 149,
#  '유': 150,
#  '첸': 151,
#  '옵': 152,
#  '봤': 153,
#  '좋': 154,
#  '복': 155,
#  '날': 156,
#  '될': 157,
#  '업': 158,
#  '펴': 159,
#  '석': 160,
#  '씨': 161,
#  '켜': 162,
#  '주': 163,
#  '조': 164,
#  '횐': 165,
#  '륙': 166,
#  '니': 167,
#  '매': 168,
#  '짧': 169,
#  '끗': 170,
#  '뜨': 171,
#  '배': 172,
#  '싫': 173,
#  '공': 174,
#  '생': 175,
#  '녁': 176,
#  '분': 177,
#  '시': 178,
#  '빙': 179,
#  '룸': 180,
#  '효': 181,
#  '국': 182,
#  '독': 183,
#  '예': 184,
#  '인': 185,
#  '쌀': 186,
#  '찌': 187,
#  '뤄': 188,
#  '런': 189,
#  '즘': 190,
#  '별': 191,
#  '홉': 192,
#  '삭': 193,
#  '중': 194,
#  '영': 195,
#  '신': 196,
#  '역': 197,
#  '입': 198,
#  '쎄': 199,
#  '꿔': 200,
#  '승': 201,
#  '춤': 202,
#  '뒤': 203,
#  '측': 204,
#  '돼': 205,
#  '딸': 206,
#  '넘': 207,
#  '엇': 208,
#  '검': 209,
#  '핑': 210,
#  '언': 211,
#  '풀': 212,
#  '맑': 213,
#  '구': 214,
#  '끓': 215,
#  '균': 216,
#  '끄': 217,
#  '홍': 218,
#  '껴': 219,
#  '락': 220,
#  '누': 221,
#  '권': 222,
#  '목': 223,
#  '낌': 224,
#  '낼': 225,
#  '대': 226,
#  '일': 227,
#  '무': 228,
#  '났': 229,
#  '안': 230,
#  '과': 231,
#  '슨': 232,
#  '둔': 233,
#  '꾸': 234,
#  '으': 235,
#  '냐': 236,
#  '찐': 237,
#  '콘': 238,
#  '티': 239,
#  '온': 240,
#  '펼': 241,
#  '를': 242,
#  '변': 243,
#  '게': 244,
#  '겠': 245,
#  '져': 246,
#  '처': 247,
#  '속': 248,
#  '쪼': 249,
#  '엠': 250,
#  '융': 251,
#  '제': 252,
#  '캄': 253,
#  '표': 254,
#  '럼': 255,
#  '플': 256,
#  '즈': 257,
#  '딘': 258,
#  '약': 259,
#  '친': 260,
#  '쩐': 261,
#  '르': 262,
#  '컨': 263,
#  '해': 264,
#  '톱': 265,
#  '쇼': 266,
#  '년': 267,
#  '던': 268,
#  '몇': 269,
#  '둘': 270,
#  '저': 271,
#  '두': 272,
#  '폭': 273,
#  '햇': 274,
#  '깐': 275,
#  '출': 276,
#  '파': 277,
#  '걸': 278,
#  '설': 279,
#  '떠': 280,
#  '전': 281,
#  '렴': 282,
#  '봅': 283,
#  '맥': 284,
#  '었': 285,
#  '3': 286,
#  '법': 287,
#  '곧': 288,
#  '테': 289,
#  '혔': 290,
#  '이': 291,
#  '회': 292,
#  '비': 293,
#  '학': 294,
#  '뷱': 295,
#  '품': 296,
#  '쉬': 297,
#  '키': 298,
#  '송': 299,
#  '튼': 300,
#  '잡': 301,
#  '겨': 302,
#  '데': 303,
#  '축': 304,
#  '얼': 305,
#  '료': 306,
#  '재': 307,
#  '략': 308,
#  '앞': 309,
#  '팅': 310,
#  '할': 311,
#  '뜻': 312,
#  '책': 313,
#  '면': 314,
#  '랍': 315,
#  '닫': 316,
#  '율': 317,
#  '타': 318,
#  '놨': 319,
#  '리': 320,
#  '밈': 321,
#  '점': 322,
#  '염': 323,
#  '돌': 324,
#  '의': 325,
#  '읊': 326,
#  '요': 327,
#  '초': 328,
#  '합': 329,
#  '릴': 330,
#  '레': 331,
#  '셋': 332,
#  '퍼': 333,
#  '엘': 334,
#  '트': 335,
#  '탐': 336,
#  '는': 337,
#  '투': 338,
#  '률': 339,
#  '커': 340,
#  '거': 341,
#  '센': 342,
#  '확': 343,
#  '층': 344,
#  '나': 345,
#  '즌': 346,
#  '수': 347,
#  '필': 348,
#  '란': 349,
#  '용': 350,
#  '뭇': 351,
#  '츠': 352,
#  '을': 353,
#  '도': 354,
#  '냄': 355,
#  '널': 356,
#  '천': 357,
#  '다': 358,
#  '적': 359,
#  '위': 360,
#  '정': 361,
#  '됐': 362,
#  '뉴': 363,
#  '혹': 364,
#  '진': 365,
#  '성': 366,
#  '채': 367,
#  '쯤': 368,
#  '작': 369,
#  '급': 370,
#  '꼈': 371,
#  '않': 372,
#  '졸': 373,
#  '형': 374,
#  '어': 375,
#  '디': 376,
#  '큰': 377,
#  '꼭': 378,
#  '멍': 379,
#  '팀': 380,
#  '블': 381,
#  '떼': 382,
#  '슈': 383,
#  '통': 384,
#  '곤': 385,
#  '밝': 386,
#  '추': 387,
#  '떴': 388,
#  '닥': 389,
#  '힌': 390,
#  '텐': 391,
#  '사': 392,
#  '살': 393,
#  '둡': 394,
#  '서': 395,
#  '맞': 396,
#  '먼': 397,
#  '터': 398,
#  '턴': 399,
#  '케': 400,
#  '높': 401,
#  '곡': 402,
#  '괄': 403,
#  '픈': 404,
#  '따': 405,
#  '워': 406,
#  '닝': 407,
#  '홈': 408,
#  '은': 409,
#  '능': 410,
#  '핵': 411,
#  '왜': 412,
#  '쳤': 413,
#  '띄': 414,
#  '실': 415,
#  '듣': 416,
#  '개': 417,
#  '퇴': 418,
#  '넷': 419,
#  '들': 420,
#  'b': 421,
#  '넣': 422,
#  '간': 423,
#  '련': 424,
#  '많': 425,
#  '북': 426,
#  '내': 427,
#  '상': 428,
#  '활': 429,
#  '결': 430,
#  '깜': 431,
#  '쓸': 432,
#  '류': 433,
#  '얀': 434,
#  '같': 435,
#  '뭘': 436,
#  '번': 437,
#  '풍': 438,
#  '단': 439,
#  '근': 440,
#  '든': 441,
#  '만': 442,
#  '환': 443,
#  '소': 444,
#  '여': 445,
#  '빌': 446,
#  '랐': 447,
#  '즉': 448,
#  '립': 449,
#  '끼': 450,
#  '깨': 451,
#  '러': 452,
#  '딪': 453,
#  '2': 454,
#  '뀐': 455,
#  '경': 456,
#  '먹': 457,
#  '또': 458,
#  '떤': 459,
#  '5': 460,
#  '평': 461,
#  '카': 462,
#  '맙': 463,
#  '굽': 464,
#  '웠': 465,
#  '강': 466,
#  '지': 467,
#  '낭': 468,
#  '올': 469,
#  '알': 470,
#  '관': 471,
#  '짜': 472,
#  '베': 473,
#  '짝': 474,
#  '때': 475,
#  '금': 476,
#  '아': 477,
#  '규': 478,
#  '종': 479,
#  '선': 480,
#  '벽': 481,
#  '택': 482,
#  '네': 483,
#  '부': 484,
#  '며': 485,
#  '너': 486,
#  '칼': 487,
#  '민': 488,
#  '룹': 489,
#  '불': 490,
#  '힐': 491,
#  '바': 492,
#  '멈': 493,
#  '였': 494,
#  '싶': 495,
#  '빵': 496,
#  '졌': 497,
#  '피': 498,
#  '노': 499,
#  '황': 500,
#  '름': 501,
#  '창': 502,
#  '받': 503,
#  '최': 504,
#  '편': 505,
#  '덜': 506,
#  '차': 507,
#  '장': 508,
#  '혀': 509,
#  '임': 510,
#  '몸': 511,
#  '혼': 512,
#  '욜': 513,
#  '완': 514,
#  '후': 515,
#  '았': 516,
#  '클': 517,
#  '침': 518,
#  '마': 519,
#  '특': 520,
#  '흥': 521,
#  '큼': 522,
#  '난': 523,
#  '림': 524,
#  '뱅': 525,
#  '각': 526,
#  '렸': 527,
#  '잠': 528,
#  '잘': 529,
#  '팝': 530,
#  'm': 531,
#  '농': 532,
#  '느': 533,
#  '밖': 534,
#  'v': 535,
#  '열': 536,
#  '헤': 537,
#  '집': 538,
#  '로': 539,
#  '있': 540,
#  '현': 541,
#  '줘': 542,
#  '토': 543,
#  '틴': 544,
#  '망': 545,
#  '문': 546,
#  '항': 547,
#  '준': 548,
#  '앰': 549,
#  '루': 550,
#  '운': 551,
#  '찮': 552,
#  '께': 553,
#  '탕': 554,
#  '론': 555,
#  '흘': 556,
#  '태': 557,
#  '칠': 558,
#  '롤': 559,
#  '잔': 560,
#  '산': 561,
#  '맛': 562,
#  '틀': 563,
#  '포': 564,
#  '픽': 565,
#  '낸': 566,
#  ' ': 567,
#  '빨': 568,
#  '뭐': 569,
#  '꽈': 570,
#  '놀': 571,
#  '물': 572,
#  '험': 573,
#  '즐': 574,
#  '둠': 575,
#  '려': 576,
#  '볼': 577,
#  '랜': 578,
#  '에': 579,
#  '래': 580,
#  '왔': 581,
#  '논': 582,
#  '읽': 583,
#  '쓰': 584,
#  '없': 585,
#  '팜': 586,
#  '씻': 587,
#  '땐': 588,
#  '애': 589,
#  '줬': 590,
#  '곳': 591,
#  '계': 592,
#  '야': 593,
#  '치': 594,
#  '손': 595,
#  '쳐': 596,
#  '본': 597,
#  '챙': 598,
#  '샷': 599,
#  '못': 600,
#  't': 601,
#  '빛': 602,
#  "'": 603,
#  '히': 604,
#  '|': 4,
#  '<pad>': 0,
#  '<s>': 1,
#  '</s>': 2,
#  '<unk>': 3}
